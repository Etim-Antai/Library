# %% [markdown]
# # Import Liberaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Import the Dataset

# %%
df =pd.read_csv(r"C:\PythonProjects\weatherdata.csv")

# %% [markdown]
# # Understanding the Data: Get an overview of your dataset

# %% [markdown]
# # Display the first few rows
# df.head()

# %%
# Summary statistics
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
# Data types of columns
df.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %% [markdown]
# # Data Cleaning: Handle missing values and perform necessary data transformations

# %%
dataset.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
# Handle missing values
df.dropna(inplace=True)  # Drop rows with missing values, or use imputation

# %%
df.isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
X['WindSpeed9am'].fillna(X['WindSpeed9am'].mean(), inplace= True)

# %%
dataset.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %% [markdown]
# # Data Visualization: Explore relationships between variables using visualizations.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Pairplot to visualize relationships between numerical variables
sns.pairplot(df[['MinTemp', 'MaxTemp', 'Rainfall', 'Sunshine', 'Humidity9am', 'Humidity3pm', 'RainToday', 'RainTomorrow']])
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df2= df.select_dtypes(include ='number')

# %%
# Correlation heatmap
corr = df2.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Feature Engineering: Create new features if necessary.

# %%
# For example, you can create new features based on existing ones
# E.g., create a feature for temperature difference between morning and afternoon
df['TempDifference'] = df['Temp3pm'] - df['Temp9am']

# %% [markdown]
# # Statistical Analysis: Perform statistical tests if applicable.

# %%
import scipy.stats as stats

# Example: T-test to compare means of two groups
group1 = df[df['RainToday'] == 'Yes']['Rainfall']
group2 = df[df['RainToday'] == 'No']['Rainfall']
t_stat, p_value = stats.ttest_ind(group1, group2)
print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: 16.597761838234078
# P-value: 2.8428393917357e-45

# %%
dataset['WindSpeed9am'].mean()
# Out:
# 9.651810584958216

# %%
dataset[(dataset['WindSpeed9am']) >=9.65]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 6        6.1     18.2       0.2          4.2       8.4          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# ..       ...      ...       ...          ...       ...         ...
# 355      9.0     20.6       0.0          9.0       6.2         ENE
# 356      3.4     15.0       0.8          4.8      11.7           S
# 357      3.2     18.0       0.0          7.4      12.2         SSE
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 3             54.0        WNW          W          30.0  ...           56
# ...

# %%
# Seasonal Trends:
# Seasonal Trends
# Group by month and calculate mean values
monthly_means = df.groupby(df.index.month).mean()

# Plot temperature and rainfall trends by month
plt.figure(figsize=(12, 6))
plt.plot(monthly_means['MinTemp'], label='Min Temperature')
plt.plot(monthly_means['MaxTemp'], label='Max Temperature')
plt.plot(monthly_means['Rainfall'], label='Rainfall')
plt.xlabel('Month')
plt.ylabel('Value')
plt.title('Seasonal Trends')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 4
#       1 # Seasonal Trends:
#       2 # Seasonal Trends
#       3 # Group by month and calculate mean values
# ----> 4 monthly_means = df.groupby(df.index.month).mean()
#       6 # Plot temperature and rainfall trends by month
#       7 plt.figure(figsize=(12, 6))
#
# AttributeError: 'Index' object has no attribute 'month'

# %%
dataset[dataset['WindGustSpeed'].isnull()]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 211     -0.1     18.0       0.0          2.0       8.6         NaN
# 271      0.8     12.2       0.0          1.8       8.6         NaN
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 211            NaN          N        NNW           2.0  ...           46
# 271            NaN          S          S          19.0  ...           49
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 211       1033.2       1028.7         1         1      5.6     17.4
# 271       1020.9       1016.8         3         1      6.5     11.2
#
#      RainToday  RISK_MM RainTomorrow
# 211         No      0.0           No
# 271         No      0.0           No
#
# [2 rows x 22 columns]

# %%
dataset.size
# Out:
# 8052

# %%
dataset.iloc[271]
# Out:
# MinTemp             0.8
# MaxTemp            12.2
# Rainfall            0.0
# Evaporation         1.8
# Sunshine            8.6
# WindGustDir         NaN
# WindGustSpeed       NaN
# WindDir9am            S
# WindDir3pm            S
# WindSpeed9am       19.0
# WindSpeed3pm         22
# Humidity9am          69
# Humidity3pm          49
# Pressure9am      1020.9
# Pressure3pm      1016.8
# Cloud9am              3
# Cloud3pm              1
# Temp9am             6.5
# Temp3pm            11.2
# RainToday            No
# RISK_MM             0.0
# RainTomorrow         No
# Name: 271, dtype: object

# %%
dataset['WindSpeed9am'].fillna(dataset['WindSpeed9am'].mean(), inplace = True)

# %%
dataset['WindGustSpeed'].describe()
# Out:
# count    364.000000
# mean      39.840659
# std       13.059807
# min       13.000000
# 25%       31.000000
# 50%       39.000000
# 75%       46.000000
# max       98.000000
# Name: WindGustSpeed, dtype: float64

# %%
dataset['WindGustSpeed'].mean()
# Out:
# 39.84065934065934

# %%
dataset['WindGustSpeed'].fillna(dataset['WindGustSpeed'].mean(), inplace = True)

# %%
dataset['WindDir3pm'].dtypes
# Out:
# dtype('O')

# %%
dataset.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
dataset2 =dataset.select_dtypes(include=['number'])

# %%
dataset2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0        8.0     24.3       0.0          3.4       6.3           30.0
# 1       14.0     26.9       3.6          4.4       9.7           39.0
# 2       13.7     23.4       3.6          5.8       3.3           85.0
# 3       13.3     15.5      39.8          7.2       9.1           54.0
# 4        7.6     16.1       2.8          5.6      10.6           50.0
# ..       ...      ...       ...          ...       ...            ...
# 361      9.0     30.7       0.0          7.6      12.1           76.0
# 362      7.1     28.4       0.0         11.6      12.7           48.0
# 363     12.5     19.9       0.0          8.4       5.3           43.0
# 364     12.5     26.9       0.0          5.0       7.1           46.0
# 365     12.3     30.2       0.0          6.0      12.6           78.0
#
#      WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
dataset2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0        8.0     24.3       0.0          3.4       6.3           30.0
# 1       14.0     26.9       3.6          4.4       9.7           39.0
# 2       13.7     23.4       3.6          5.8       3.3           85.0
# 3       13.3     15.5      39.8          7.2       9.1           54.0
# 4        7.6     16.1       2.8          5.6      10.6           50.0
# ..       ...      ...       ...          ...       ...            ...
# 361      9.0     30.7       0.0          7.6      12.1           76.0
# 362      7.1     28.4       0.0         11.6      12.7           48.0
# 363     12.5     19.9       0.0          8.4       5.3           43.0
# 364     12.5     26.9       0.0          5.0       7.1           46.0
# 365     12.3     30.2       0.0          6.0      12.6           78.0
#
#      WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
X=dataset2.drop(['Sunshine','WindGustSpeed','WindSpeed9am','RISK_MM'], axis =1)
y=dataset2['RISK_MM']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test, y_train, y_test =train_test_split(X, y, test_size =0.6, random_state =0)

# %%
mymodel=LinearRegression()

# %%
mymodel.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions =mymodel.predict(X_test)

# %%
(predictions -y_test).round()
# Out:
# 106     1.0
# 259     3.0
# 45      7.0
# 26      2.0
# 78    -15.0
#        ...
# 150     1.0
# 225     2.0
# 81      4.0
# 1      -1.0
# 153    -2.0
# Name: RISK_MM, Length: 122, dtype: float64

# %%
mymodel.score(X_test, y_test)
# Out:
# 0.1887979260517404
